# %%
#Simone Shree Pathak Baiju
class BankAccount:
    def __init__(self, name, account_number, balance=0):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited NPR {amount}. New balance: NPR {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"Withdrawn NPR {amount}. New balance: NPR {self.balance}")

    def get_balance(self):
        print(f"{self.name} | Balance: NPR {self.balance}")

# %%
#Simone Shree Pathak Baiju
accounts = [
    ("Ramesh Thapa", "A001", 5000),
    ("Sunita Karki", "A002", 0),
    ("Bikash Rai", "A003", 12000),
]

a1 = BankAccount(*accounts[0])
a2 = BankAccount(*accounts[1])
a3 = BankAccount(*accounts[2])

# %%
#Simone Shree Pathak Baiju
a2.deposit(3000)
a3.withdraw(15000)
a1.withdraw(2000)
a1.get_balance()
a2.get_balance()
a3.get_balance()
# Out:
# Deposited NPR 3000. New balance: NPR 3000
# Insufficient funds
# Withdrawn NPR 2000. New balance: NPR 3000
# Ramesh Thapa | Balance: NPR 3000
# Sunita Karki | Balance: NPR 3000
# Bikash Rai | Balance: NPR 12000

# %%
#Simone Shree Pathak Baiju
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def average(self):
        return sum(self.marks) / len(self.marks)

    def grade(self):
        avg = self.average()
        if avg >= 80:
            return "A"
        elif avg >= 65:
            return "B"
        elif avg >= 50:
            return "C"
        elif avg >= 40:
            return "D"
        else:
            return "F"

    def display(self):
        avg = self.average()
        result = "Pass" if avg >= 40 else "Fail"
        print(f"{self.name} | Average: {avg:.1f} | Grade: {self.grade()} | {result}")

# %%
#Simone Shree Pathak Baiju
students = [
    ("Aarav", [78, 85, 60, 90, 72]),
    ("Sita", [45, 50, 38, 60, 55]),
    ("Bishal", [30, 25, 40, 35, 28]),
    ("Priya", [90, 88, 95, 92, 87]),
]

for name, marks in students:
    s = Student(name, marks)
    s.display()
# Out:
# Aarav | Average: 77.0 | Grade: B | Pass
# Sita | Average: 49.6 | Grade: D | Pass
# Bishal | Average: 31.6 | Grade: F | Fail
# Priya | Average: 90.4 | Grade: A | Pass

# %%
#Simone Shree Pathak Baiju
class DeliveryPartner:
    def __init__(self, name, partner_id, deliveries):
        self.name = name
        self.partner_id = partner_id
        self.deliveries = deliveries

    def total_earning(self):
        return 0

    def display(self):
        print(f"{self.name} ({self.partner_id}) | Deliveries: {self.deliveries} | Earning: NPR {self.total_earning()}")

# %%
#Simone Shree Pathak Baiju
class BikeRider(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, km_travelled):
        super().__init__(name, partner_id, deliveries)
        self.km_travelled = km_travelled

    def total_earning(self):
        return (self.deliveries * 80) + (self.km_travelled * 5)

# %%
#Simone Shree Pathak Baiju
class Walker(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, rainy_deliveries):
        super().__init__(name, partner_id, deliveries)
        self.rainy_deliveries = rainy_deliveries

    def total_earning(self):
        return (self.deliveries * 60) + (self.rainy_deliveries * 50)

# %%
#Simone Shree Pathak Baiju
class CarDriver(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, fuel_cost):
        super().__init__(name, partner_id, deliveries)
        self.fuel_cost = fuel_cost

    def total_earning(self):
        return (self.deliveries * 120) - self.fuel_cost

# %%
#Simone Shree Pathak Baiju
partners = [
    BikeRider("Santosh Rai", "B-01", 15, 42),
    Walker("Kabita Maharjan", "W-01", 18, 5),
    CarDriver("Roshan KC", "C-01", 20, 850),
]

for p in partners:
    p.display()

top = max(partners, key=lambda p: p.total_earning())
print(f"\nHighest earning: {top.name} with NPR {top.total_earning()}")
# Out:
# Santosh Rai (B-01) | Deliveries: 15 | Earning: NPR 1410
# Kabita Maharjan (W-01) | Deliveries: 18 | Earning: NPR 1330
# Roshan KC (C-01) | Deliveries: 20 | Earning: NPR 1550
#
# Highest earning: Roshan KC with NPR 1550

# %%
#Simone Shree Pathak Baiju
class Bus:
    def __init__(self, route, total_seats):
        self.route = route
        self.total_seats = total_seats
        self.booked = {}

    def book_seat(self, seat_number, passenger_name):
        if seat_number in self.booked:
            print(f"Seat {seat_number} already booked")
        else:
            self.booked[seat_number] = passenger_name
            print(f"Seat {seat_number} booked for {passenger_name}")

    def available_seats(self):
        return self.total_seats - len(self.booked)

    def passenger_list(self):
        print("\nPassenger List:")
        for seat, name in self.booked.items():
            print(f"Seat {seat}: {name}")

# %%
#Simone Shree Pathak Baiju
bus = Bus("Kathmandu - Pokhara", 10)

bookings = [
    (3, "Ramila Shrestha"),
    (7, "Deepak Gurung"),
    (3, "Anita Rai"),
    (1, "Prakash Magar"),
    (7, "Suman Tamang"),
]

for seat, name in bookings:
    bus.book_seat(seat, name)

print(f"\nAvailable seats: {bus.available_seats()}")
bus.passenger_list()
# Out:
# Seat 3 booked for Ramila Shrestha
# Seat 7 booked for Deepak Gurung
# Seat 3 already booked
# Seat 1 booked for Prakash Magar
# Seat 7 already booked
#
# Available seats: 7
#
# Passenger List:
# Seat 3: Ramila Shrestha
# Seat 7: Deepak Gurung
# Seat 1: Prakash Magar
